# %%
import requests
from bs4 import BeautifulSoup
import sys
import re

# %%
Country_Input= input("Input the ISO 3166-1 country code of the country you would like to seacrh in?\n").lower()
Country_Codes = ('gb', 'us','at','au','be','br','ca','ch','de','es','fr','in','it','mx','nl','nz','pl','sg','za')

if Country_Input in Country_Codes:
    print("This is a valid country code")
else:
    print(f"{Country_Input} is not available/invalid")
    sys.exit()
# Out:
# This is a valid country code

# %%
Choice = input("(Choose option 1 or 2)\nWould like to see\n1. What your pay will be with your current skills\n2. What skills have the most pay in general")
if Choice == '1':
    Skills = input("Input your current skill(s)(if plural separate by comma): ")
    url = f"http://api.adzuna.com/v1/api/jobs/{Country_Input}/search/1?app_id=bbb231a1&app_key=ead6a75aff389175119f5fc5fd7d97cc&what={Skills}&content-type=application/json"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
Data = response.json()
Data
# Out:
# {'mean': 44900.57,
#  'results': [{'description': 'Are you ready to take your career to new heights? Become one of EasyJets incredible Service Excellence Specialists and help make everyones journey an unforgettable one! Start date: March 2026 Location: Glasgow- This is an office based role only. There is no option to work from home for this role. There is also no part time hours available Salary: £12.21 p/h Shifts: Full time - 40 hrs per w e ek - 09.00-18.00 - Mon - Fri ( There is a possibility that weekend working and later operating hours may…',
#    'title': 'Service Excellence Specialists - EasyJet',
#    'longitude': -4.031733,
#    'salary_min': 40000,
#    'redirect_url': 'https://www.adzuna.co.uk/jobs/land/ad/5632449165?se=VrImab4Q8RGHm4c4GRrdVA&utm_medium=api&utm_source=bbb231a1&v=9064FF9677228A419F3849805AE305672D9C4268',
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'Teleperformance'},
#    'salary_max': 40000,
#    'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'label': 'Customer Services Jobs',
#     'tag': 'customer-services-jobs'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'latitude': 55.859699,
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiVnJJbWFiNFE4UkdIbTRjNEdScmRWQSIsImkiOiI1NjMyNDQ5MTY1In0.QBVvDhvuyGh9KfaTKJIKo33TLW_yhNeCucesg9zo_Hs',
#    'id': '5632449165',
#    'created': '2026-02-16T23:56:00Z',
#    'salary_is_predicted': '1',
#    'location': {'display_name': 'Glenboig, Coatbridge',
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['UK', 'Scotland', 'North Lanarkshire', 'Coatbridge', 'Glenboig']},
#    'contract_time': 'full_time'},
#   {'category': {'tag': 'customer-services-jobs',
#     'label': 'Customer Services Jobs',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'salary_max': 39857.7,
#    'redirect_url': 'https://www.adzuna.co.uk/jobs/land/ad/5632449166?se=VrImab4Q8RGHm4c4GRrdVA&utm_medium=api&utm_source=bbb231a1&v=F5E4BA6665BC2A985E850671C91D661378ED2599',
#    'salary_min': 39857.7,
#    'company': {'display_name': 'Teleperformance',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'description': 'Are you ready to take your career to new heights? Become one of EasyJets incredible Service Excellence Specialists and help make everyones journey an unforgettable one! Start date: March 2026 Location: Glasgow- This is an office based role only. There is no option to work from home for this role. There is also no part time hours available Salary: £12.21 p/h Shifts: Full time - 40 hrs per w e ek - 09.00-18.00 - Mon - Fri ( There is a possibility that weekend working and later operating hours may…',
#    'title': 'Service Excellence Specialists - EasyJet',
#    'longitude': -4.675275,
#    'created': '2026-02-16T23:56:00Z',
#    'salary_is_predicted': '1',
#    'contract_time': 'full_time',
#    'location': {'area': ['UK',
#      'Scotland',
#      'Inverclyde',
#      'Port Glasgow',
#      'Langbank'],
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'display_name': 'Langbank, Port Glasgow'},
#    'id': '5632449166',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiVnJJbWFiNFE4UkdIbTRjNEdScmRWQSIsImkiOiI1NjMyNDQ5MTY2In0.sPr-5MMy1fG4Q8rPdU-nE80W-XwD45W5vTC7C8yvfsY',
#    'latitude': 55.905175},
#   {'latitude': 55.612341,
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTYzMjQ0OTE1MCIsInMiOiJWckltYWI0UThSR0htNGM0R1JyZFZBIn0.mtKxRembqXQVGb781fkNTDFJpMeNux8gYgKfFEiPNeE',
#    'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['UK', 'Scotland', 'East Ayrshire', 'Kilmarnock', 'Annandale'],
#     'display_name': 'Annandale, Kilmarnock'},
#    'contract_time': 'full_time',
#    'created': '2026-02-16T23:55:59Z',
#    'salary_is_predicted': '1',
#    'id': '5632449150',
#    'redirect_url': 'https://www.adzuna.co.uk/jobs/land/ad/5632449150?se=VrImab4Q8RGHm4c4GRrdVA&utm_medium=api&utm_source=bbb231a1&v=42C8828DB0F5AAC483B9A1EF78819D5434D37628',
#    'salary_min': 41507.12,
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'Teleperformance'},
#    'longitude': -4.523495,
#    'description': 'Are you ready to take your career to new heights? Become one of EasyJets incredible Service Excellence Specialists and help make everyones journey an unforgettable one! Start date: March 2026 Location: Glasgow- This is an office based role only. There is no option to work from home for this role. There is also no part time hours available Salary: £12.21 p/h Shifts: Full time - 40 hrs per w e ek - 09.00-18.00 - Mon - Fri ( There is a possibility that weekend working and later operating hours may…',
#    'title': 'Service Excellence Specialists - EasyJet',
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'category': {'tag': 'customer-services-jobs',
#     '__CLASS__': 'Adzuna::API::Response::Category',
#     'label': 'Customer Services Jobs'},
#    'salary_max': 41507.12},
#   {'title': 'Service Excellence Specialists - EasyJet',
#    'description': 'Are you ready to take your career to new heights? Become one of EasyJets incredible Service Excellence Specialists and help make everyones journey an unforgettable one! Start date: March 2026 Location: Glasgow- This is an office based role only. There is no option to work from home for this role. There is also no part time hours available Salary: £12.21 p/h Shifts: Full time - 40 hrs per w e ek - 09.00-18.00 - Mon - Fri ( There is a possibility that weekend working and later operating hours may…',
#    'longitude': -4.021434,
#    'company': {'display_name': 'Teleperformance',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'redirect_url': 'https://www.adzuna.co.uk/jobs/land/ad/5632449164?se=VrImab4Q8RGHm4c4GRrdVA&utm_medium=api&utm_source=bbb231a1&v=7C6CD72F9A786CC79870537FDF0AE7B3E2C3AF5A',
#    'salary_min': 40670.15,
#    'salary_max': 40670.15,
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'category': {'label': 'Customer Services Jobs',
#     '__CLASS__': 'Adzuna::API::Response::Category',
#     'tag': 'customer-services-jobs'},
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiVnJJbWFiNFE4UkdIbTRjNEdScmRWQSIsImkiOiI1NjMyNDQ5MTY0In0.0im09KkL54VM8QiiYewggEZEvRB68Ko26unizihDJn0',
#    'latitude': 55.81845,
#    'id': '5632449164',
#    'salary_is_predicted': '1',
#    'created': '2026-02-16T23:56:00Z',
#    'contract_time': 'full_time',
#    'location': {'area': ['UK',
#      'Scotland',
#      'North Lanarkshire',
#      'Bellshill',
#      'Orbiston'],
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'display_name': 'Orbiston, Bellshill'}},
#   {'contract_time': 'full_time',
#    'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['UK', 'Scotland', 'County Stirling', 'Stirling', 'Throsk'],
#     'display_name': 'Throsk, Stirling'},
#    'created': '2026-02-16T23:56:00Z',
#    'salary_is_predicted': '1',
#    'id': '5632449167',
#    'latitude': 56.103948,
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiVnJJbWFiNFE4UkdIbTRjNEdScmRWQSIsImkiOiI1NjMyNDQ5MTY3In0.cDRSjhir7QAssm21yD36L-KtQDaj8_tlUarSFNjQYIw',
#    'category': {'label': 'Customer Services Jobs',
#     '__CLASS__': 'Adzuna::API::Response::Category',
#     'tag': 'customer-services-jobs'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'salary_max': 39349.42,
#    'redirect_url': 'https://www.adzuna.co.uk/jobs/land/ad/5632449167?se=VrImab4Q8RGHm4c4GRrdVA&utm_medium=api&utm_source=bbb231a1&v=9529CAE4F4D090D7B1126998E998193636ED981A',
#    'salary_min': 39349.42,
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'Teleperformance'},
#    'longitude': -3.833209,
#    'description': 'Are you ready to take your career to new heights? Become one of EasyJets incredible Service Excellence Specialists and help make everyones journey an unforgettable one! Start date: March 2026 Location: Glasgow- This is an office based role only. There is no option to work from home for this role. There is also no part time hours available Salary: £12.21 p/h Shifts: Full time - 40 hrs per w e ek - 09.00-18.00 - Mon - Fri ( There is a possibility that weekend working and later operating hours may…',
#    'title': 'Service Excellence Specialists - EasyJet'},
#   {'category': {'tag': 'customer-services-jobs',
#     '__CLASS__': 'Adzuna::API::Response::Category',
#     'label': 'Customer Services Jobs'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'salary_max': 34145.79,
#    'company': {'display_name': 'Teleperformance',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'redirect_url': 'https://www.adzuna.co.uk/jobs/land/ad/5632449160?se=VrImab4Q8RGHm4c4GRrdVA&utm_medium=api&utm_source=bbb231a1&v=2D8D67BAEFF144242E89173AA229B91ADCCE296C',
#    'salary_min': 34145.79,
#    'title': 'Service Excellence Specialists - EasyJet',
#    'description': 'Are you ready to take your career to new heights? Become one of EasyJets incredible Service Excellence Specialists and help make everyones journey an unforgettable one! Start date: March 2026 Location: Glasgow- This is an office based role only. There is no option to work from home for this role. There is also no part time hours available Salary: £12.21 p/h Shifts: Full time - 40 hrs per w e ek - 09.00-18.00 - Mon - Fri ( There is a possibility that weekend working and later operating hours may…',
#    'longitude': -3.967539,
#    'salary_is_predicted': '1',
#    'created': '2026-02-16T23:56:00Z',
#    'contract_time': 'full_time',
#    'location': {'area': ['UK',
#      'Scotland',
#      'South Lanarkshire',
#      'Larkhall',
#      'Birkenshaw'],
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'display_name': 'Birkenshaw, Larkhall'},
#    'id': '5632449160',
#    'latitude': 55.724687,
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiVnJJbWFiNFE4UkdIbTRjNEdScmRWQSIsImkiOiI1NjMyNDQ5MTYwIn0.jLW7_Rr3WyklKCq8JTFYDhJALxonRxrzLrMlGcIc0Ns'},
#   {'salary_is_predicted': '1',
#    'created': '2026-02-16T23:56:00Z',
#    'contract_time': 'full_time',
#    'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['UK', 'Scotland', 'South Lanarkshire', 'Hamilton', 'Ferniegair'],
#     'display_name': 'Ferniegair, Hamilton'},
#    'id': '5632449158',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTYzMjQ0OTE1OCIsInMiOiJWckltYWI0UThSR0htNGM0R1JyZFZBIn0.dJ-T_h4R2tNCjaXnh61_TLlxN9As8Y21nd9gsDmizoE',
#    'latitude': 55.770749,
#    'category': {'tag': 'customer-services-jobs',
#     'label': 'Customer Services Jobs',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'salary_max': 35623.9,
#    'company': {'display_name': 'Teleperformance',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'redirect_url': 'https://www.adzuna.co.uk/jobs/land/ad/5632449158?se=VrImab4Q8RGHm4c4GRrdVA&utm_medium=api&utm_source=bbb231a1&v=22EAAA3C755C794E11DA6236F270B8564C9FF359',
#    'salary_min': 35623.9,
#    'title': 'Service Excellence Specialists - EasyJet',
#    'description': 'Are you ready to take your career to new heights? Become one of EasyJets incredible Service Excellence Specialists and help make everyones journey an unforgettable one! Start date: March 2026 Location: Glasgow- This is an office based role only. There is no option to work from home for this role. There is also no part time hours available Salary: £12.21 p/h Shifts: Full time - 40 hrs per w e ek - 09.00-18.00 - Mon - Fri ( There is a possibility that weekend working and later operating hours may…',
#    'longitude': -4.054825},
#   {'longitude': -4.843392,
#    'description': 'Are you ready to take your career to new heights? Become one of EasyJets incredible Service Excellence Specialists and help make everyones journey an unforgettable one! Start date: March 2026 Location: Glasgow- This is an office based role only. There is no option to work from home for this role. There is also no part time hours available Salary: £12.21 p/h Shifts: Full time - 40 hrs per w e ek - 09.00-18.00 - Mon - Fri ( There is a possibility that weekend working and later operating hours may…',
#    'title': 'Service Excellence Specialists - EasyJet',
#    'redirect_url': 'https://www.adzuna.co.uk/jobs/land/ad/5632449152?se=VrImab4Q8RGHm4c4GRrdVA&utm_medium=api&utm_source=bbb231a1&v=7B842AEC870BB2EF96372E394ABC3324828404AE',
#    'salary_min': 38216.39,
#    'company': {'display_name': 'Teleperformance',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'salary_max': 38216.39,
#    'category': {'label': 'Customer Services Jobs',
#     '__CLASS__': 'Adzuna::API::Response::Category',
#     'tag': 'customer-services-jobs'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTYzMjQ0OTE1MiIsInMiOiJWckltYWI0UThSR0htNGM0R1JyZFZBIn0.KoKXEim3opv2UMFslFTkXPpFUhp3Xv_4ODNNlON1Xak',
#    'latitude': 55.838602,
#    'id': '5632449152',
#    'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['UK', 'Scotland', 'North Ayrshire', 'Skelmorlie', 'Meigle'],
#     'display_name': 'Meigle, Skelmorlie'},
#    'contract_time': 'full_time',
#    'created': '2026-02-16T23:55:59Z',
#    'salary_is_predicted': '1'},
#   {'category': {'label': 'Customer Services Jobs',
#     '__CLASS__': 'Adzuna::API::Response::Category',
#     'tag': 'customer-services-jobs'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'salary_max': 35943.86,
#    'redirect_url': 'https://www.adzuna.co.uk/jobs/land/ad/5632449145?se=VrImab4Q8RGHm4c4GRrdVA&utm_medium=api&utm_source=bbb231a1&v=1AF8D21CFFD5BA3CFD44B49D9AF82A92BD5C4535',
#    'salary_min': 35943.86,
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'Teleperformance'},
#    'longitude': -4.598736,
#    'description': 'Are you ready to take your career to new heights? Become one of EasyJets incredible Service Excellence Specialists and help make everyones journey an unforgettable one! Start date: March 2026 Location: Glasgow- This is an office based role only. There is no option to work from home for this role. There is also no part time hours available Salary: £12.21 p/h Shifts: Full time - 40 hrs per w e ek - 09.00-18.00 - Mon - Fri ( There is a possibility that weekend working and later operating hours may…',
#    'title': 'Service Excellence Specialists - EasyJet',
#    'location': {'area': ['UK',
#      'Scotland',
#      'North Ayrshire',
#      'Irvine',
#      'Springside'],
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'display_name': 'Springside, Irvine'},
#    'contract_time': 'full_time',
#    'created': '2026-02-16T23:55:59Z',
#    'salary_is_predicted': '1',
#    'id': '5632449145',
#    'latitude': 55.614809,
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTYzMjQ0OTE0NSIsInMiOiJWckltYWI0UThSR0htNGM0R1JyZFZBIn0.VpjGK5JifccH7bmbeO-QfmHPByv4a6V4OQTrhWSupis'},
#   {'company': {'display_name': 'Teleperformance',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'salary_min': 37157.42,
#    'redirect_url': 'https://www.adzuna.co.uk/jobs/land/ad/5632449156?se=VrImab4Q8RGHm4c4GRrdVA&utm_medium=api&utm_source=bbb231a1&v=705E5B8153FCF07C22260CC80AA9D626EE877178',
#    'title': 'Service Excellence Specialists - EasyJet',
#    'description': 'Are you ready to take your career to new heights? Become one of EasyJets incredible Service Excellence Specialists and help make everyones journey an unforgettable one! Start date: March 2026 Location: Glasgow- This is an office based role only. There is no option to work from home for this role. There is also no part time hours available Salary: £12.21 p/h Shifts: Full time - 40 hrs per w e ek - 09.00-18.00 - Mon - Fri ( There is a possibility that weekend working and later operating hours may…',
#    'longitude': -4.407602,
#    'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'label': 'Customer Services Jobs',
#     'tag': 'customer-services-jobs'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'salary_max': 37157.42,
#    'latitude': 55.913577,
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiVnJJbWFiNFE4UkdIbTRjNEdScmRWQSIsImkiOiI1NjMyNDQ5MTU2In0.cXtoQzJxMTtaO9s4QcNSF-_pzpz4ZJ33PknM0FeKCZ8',
#    'salary_is_predicted': '1',
#    'created': '2026-02-16T23:56:00Z',
#    'contract_time': 'full_time',
#    'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['UK',
#      'Scotland',
#      'West Dunbartonshire',
#      'Clydebank',
#      'Duntocher'],
#     'display_name': 'Duntocher, Clydebank'},
#    'id': '5632449156'}],
#  'count': 113292,
#  '__CLASS__': 'Adzuna::API::Response::JobSearchResults'}

# %%
Min_List = []
Max_List = []
for i in range(len(Data['results'])):
    Salary_min = Data['results'][i]['salary_min']
    Salary_max = Data['results'][i]['salary_max']
    Max_List.append(Salary_max)
    Min_List.append(Salary_min)

Max_Estimate = sum(Max_List)/len(Max_List)
Min_Estimate = sum(Min_List)/len(Min_List)
if Max_Estimate == Min_Estimate:
    print(f"Estimated Salary is {Min_Estimate}")
else:
    print(f"Otimistic estimated salary: {Max_Estimate}")
    print(f"Conservative Estimated salary: {Min_Estimate}")
# Out:
# Estimated Salary is 38247.175
